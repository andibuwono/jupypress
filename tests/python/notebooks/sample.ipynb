# %% [markdown]
# # Welcome to JupyPress
#
# Create presentations from Jupyter notebooks

# %% [markdown]
# ## Features

# %% [markdown]
# - Multiple slide layouts
# - Custom theming
# - Live preview
# - Export to standalone HTML

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Sine Wave')
plt.show()
